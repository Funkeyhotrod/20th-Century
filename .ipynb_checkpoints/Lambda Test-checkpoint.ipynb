# %%
import pandas as pd

# %%
data = pd.DataFrame({'Kirby Copy Ability': ['Animal', 'Archer', 'Artist', 'Backdrop', 'Ball', 'Balloon', 'Beam', 'Beetle', 'Bell', 'Bomb', 'Bubble', 'Burning', 'Circus', 'Cleaning', 'Cook', 'Copy', 'Crash', 'Cupid', 'Cutter', 'Doctor', 'Drill', 'ESP', 'Festival', 'Fighter', 'Fire', 'Freeze',
                                            'Ghost', 'Hammer', 'Hi-Jump', 'Ice', 'Jelly', 'Jet', 'Laser', 'Leaf', 'Light', 'Magic', 'Mecha', 'Metal', 'Mike', 'Mini', 'Mirror', 'Missile', 'Needle', 'Ninja', 'Paint', 'Parasol', 'Plasma', 'Poison', 'Ranger', 'Sand', 'Sleep', 'Smash Bros.',
                                            'Spark', 'Spear', 'Spider', 'Staff', 'Stone', 'Suplex', 'Sword', 'Throw', 'Tornado', 'UFO', 'Water', 'Wheel', 'Whip', 'Wing', 'Wrestler', 'Yo-Yo'], 
                     'Number of game appearances': [1,4,2,2,2,1,14,5,3,15,1,10,2,2,4,2,12,2,18,2,2,2,2,13,13,5,1,15,7,16,1,3,4,4,2,2,1,1,10,1,4,2,14,11,2,18,4,1,1,1,14,3,15,4,1,2,17,3,17,4,12,6,4,12,9,8,1,4]})

# %%
pd.options.display.max_rows = None

# %%
data
# Out:
#    Kirby Copy Ability  Number of game appearances
# 0              Animal                           1
# 1              Archer                           4
# 2              Artist                           2
# 3            Backdrop                           2
# 4                Ball                           2
# 5             Balloon                           1
# 6                Beam                          14
# 7              Beetle                           5
# 8                Bell                           3
# 9                Bomb                          15
# 10             Bubble                           1
# 11            Burning                          10
# 12             Circus                           2
# 13           Cleaning                           2
# 14               Cook                           4
# 15               Copy                           2
# 16              Crash                          12
# 17              Cupid                           2
# ...

# %%
# There are 24 Kirby games with copy abilities
data['% of appearances in franchise'] = data['Number of game appearances'].apply(lambda x: x/24*100)

# %%
data['Rarity'] = data['Number of game appearances'].apply(lambda x: 'Common' if x > 16 else ('Occasional' if x > 8 else 'Rare'))

# %%
data
# Out:
#    Kirby Copy Ability  Number of game appearances  \
# 0              Animal                           1
# 1              Archer                           4
# 2              Artist                           2
# 3            Backdrop                           2
# 4                Ball                           2
# 5             Balloon                           1
# 6                Beam                          14
# 7              Beetle                           5
# 8                Bell                           3
# 9                Bomb                          15
# 10             Bubble                           1
# 11            Burning                          10
# 12             Circus                           2
# 13           Cleaning                           2
# 14               Cook                           4
# 15               Copy                           2
# 16              Crash                          12
# 17              Cupid                           2
# ...
